# %% [markdown]
# # Data Folder
#
# This folder contains all datasets used in the project.
#
# - `raw/`: Original data (should not be modified)
# - `processed/`: Cleaned or transformed data
#
# All analysis in the notebooks is based on these datasets.
