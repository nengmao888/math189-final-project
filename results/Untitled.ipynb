# %% [markdown]
# # Results
#
# This folder contains outputs from the analysis.
#
# Examples:
# - Figures (plots, charts)
# - Tables
# - Model results
#
# These results are generated from the notebooks.
